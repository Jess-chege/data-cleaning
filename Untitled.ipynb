# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd

df =pd.read_csv ('Web_Development.csv')

df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    41295.0               Learn HTML5 Programming From Scratch
# 1    59014.0                     Coding for Entrepreneurs Basic
# 2   625204.0                         The Web Developer Bootcamp
# 3   173548.0  Build Your First Website in 1 Week with HTML5 ...
# 4   764164.0              The Complete Web Developer Course 2.0
# 5   473160.0  Web Design for Web Developers: Build Beautiful...
# 6    94430.0             Learn Javascript & JQuery From Scratch
# 7   130064.0  Practical PHP: Master the Basics and Code Dyna...
# 8   364426.0          JavaScript: Understanding the Weird Parts
# 9   756150.0  Angular 4 (formerly Angular 2) - The Complete ...
#
#                                                  url  price  num_subscribers  \
# 0  https://www.udemy.com/learn-html5-programming-...    0.0         268923.0
# 1  https://www.udemy.com/coding-for-entrepreneurs...    0.0         161029.0
# ...

# %%
df.tail(10)
# Out:
#       course_id                                       course_title  \
# 1195  1179104.0  Learning Path: React: Make Stunning React Webs...
# 1196  1194232.0  Learning Path: Akka: Building Applications and...
# 1197  1152012.0                Adobe Experience Manager CMS Basics
# 1198  1170920.0         Node:js : Building Rest Apis with Sails.js
# 1199  1131732.0  Set up a localhost Web Server for Faster Websi...
# 1200  1227578.0           Learning Path: The Road to Elasticsearch
# 1201  1277924.0                            Angular 4 Front To Back
# 1202  1248172.0            Essentials of Spring 5.0 for Developers
# 1203  1250934.0  Display and analyze GIS data on the web with L...
# 1204  1270222.0  Learning Path: Web Applications with Spring an...
#
#                                                     url  price  \
# 1195  https://www.udemy.com/learning-path-react-make...  200.0
# 1196  https://www.udemy.com/learning-path-akka-build...  200.0
# ...

# %%
df.isnull().sum()
# Out:
# course_id              2
# course_title           2
# url                    2
# price                  2
# num_subscribers        2
# num_reviews            2
# num_lectures           2
# level                  2
# Rating                 2
# content_duration       2
# published_timestamp    2
# subject                1
# dtype: int64

# %%
new_df= df.dropna()
print(new_df.to_string())
# Out:
#       course_id                                                                                course_title                                                                                            url  price  num_subscribers  num_reviews  num_lectures               level  Rating  content_duration   published_timestamp                   subject
# 0       41295.0                                                        Learn HTML5 Programming From Scratch                                    https://www.udemy.com/learn-html5-programming-from-scratch/    0.0         268923.0       8629.0          45.0      Beginner Level    0.82         10.500000  2013-02-14T07:03:41Z  Subject: Web Development
# ...

# %%
new_df
# Out:
#       course_id                                       course_title  \
# 0       41295.0               Learn HTML5 Programming From Scratch
# 1       59014.0                     Coding for Entrepreneurs Basic
# 2      625204.0                         The Web Developer Bootcamp
# 3      173548.0  Build Your First Website in 1 Week with HTML5 ...
# 4      764164.0              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1200  1227578.0           Learning Path: The Road to Elasticsearch
# 1201  1277924.0                            Angular 4 Front To Back
# 1202  1248172.0            Essentials of Spring 5.0 for Developers
# 1203  1250934.0  Display and analyze GIS data on the web with L...
# 1204  1270222.0  Learning Path: Web Applications with Spring an...
#
#                                                     url  price  \
# 0     https://www.udemy.com/learn-html5-programming-...    0.0
# ...

# %%
new_df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# Rating                 0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
new_df.to_csv('development.csv')
